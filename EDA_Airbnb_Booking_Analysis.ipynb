# %% [markdown]
# <a href="https://colab.research.google.com/github/abhishekdhasmana17/Airbnb-EDA/blob/main/EDA_Airbnb_Booking_Analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Project Name**    -  ***Airbnb Booing Analysis***

# %% [markdown]
# ##### **Project Type**    - EDA
# ##### **Contribution**    - Team
# ##### **Team Member 1 -** Abhishek Dhasmana (Me)
# ##### **Team Member 2 -** Nishant Kalanta (leader)
# ##### **Team Member 3 -** Dhrishanda Mehdi
# ##### **Team Member 4 -** Ramkrishan shahi
# ##### **Team Member 5 -** Himanshu Awasthi

# %% [markdown]
# # **Project Summary -**

# %% [markdown]
# Write the summary here within 500-600 words.
#
# Airbnb (ABNB) is an online marketplace that connects people who want to rent a home with people who are looking for accommodation in a specific area.
#
# Problem statement:
# Big firms like Airbnb generate data constantly, every day the number of data generated is roughly in millions. So, the real challenge is to handle this data and handling data is vital for any firm to be on the right track, to know what customer want and are they getting what they asked for?
# All these things are cleared or answered by handling the data or doing DATA ANALYSIS.
#
# Approach:
# Whenever we are dealing with huge amount of data, it is the best to start by dealing with null values. Then, find the correlation matrix to understand the logic between two variables after that we can start with our Exploratory Data analysis.
#
#
# I used stackoverflow (https://stackoverflow.com/) to solve the problems I have faced throughout the analysis.

# %% [markdown]
# # **GitHub Link -**

# %% [markdown]
# Provide your GitHub Link here.
#
# https://github.com/abhishekdhasmana17/Airbnb-EDA

# %% [markdown]
# # **Problem Statement**

# %% [markdown]
# **Write Problem Statement Here.**
#
# Big firms like Airbnb generate data constantly, every day the number of data generated is roughly in millions. So, the real challenge is to handle this data and handling data is vital for any firm to be on the right track, to know what customer want and are they getting what they asked for? All these things are cleared or answered by handling the data or doing DATA ANALYSIS.
#
# **Explore and analyze the data to discover key understandings (not limited to these) such as :**
#
# What can we learn about different hosts and areas?
#
# What can we learn from predictions? (ex: locations, prices, reviews, etc)
#
# Which hosts are the busiest and why?
#
# Is there any noticeable difference of traffic among different areas and what could be the reason for it?

# %% [markdown]
# #### **Define Your Business Objective?**

# %% [markdown]
# Our objective is to analyze and understand the dataset. What people/guests have been preferring so far. so that we as Airbnb can modify/customize service based on the preference.

# %% [markdown]
# # **General Guidelines** : -

# %% [markdown]
# 1.   Well-structured, formatted, and commented code is required.
# 2.   Exception Handling, Production Grade Code & Deployment Ready Code will be a plus. Those students will be awarded some additional credits.
#
#      The additional credits will have advantages over other students during Star Student selection.
#
#              [ Note: - Deployment Ready Code is defined as, the whole .ipynb notebook should be executable in one go
#                        without a single error logged. ]
#
# 3.   Each and every logic should have proper comments.
# 4. You may add as many number of charts you want. Make Sure for each and every chart the following format should be answered.
#
#
# ```
# # Chart visualization code
# ```
#
#
# *   Why did you pick the specific chart?
# *   What is/are the insight(s) found from the chart?
# * Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.
#
# 5. You have to create at least 20 logical & meaningful charts having important insights.
#
#
# [ Hints : - Do the Vizualization in  a structured way while following "UBM" Rule.
#
# U - Univariate Analysis,
#
# B - Bivariate Analysis (Numerical - Categorical, Numerical - Numerical, Categorical - Categorical)
#
# M - Multivariate Analysis
#  ]

# %% [markdown]
# # ***Let's Begin !***

# %% [markdown]
# ## ***1. Know Your Data***

# %% [markdown]
# ### Import Libraries

# %%
# Import Libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import missingno as msno

# %% [markdown]
# ### Dataset Loading

# %%
# Load Dataset
url='https://drive.google.com/file/d/1PjjRk7i7duaH-kfRWAl0OfBK56pplZsD/view?usp=sharing'
url='https://drive.google.com/uc?id=' + url.split('/')[-2]
df = pd.read_csv(url)

# %% [markdown]
# ### Dataset First View

# %%
# Dataset First Loop
# When using priint command our dataset is taking unwanted form. so, we are just calling the variable or the dataset.
df
# Out:
#              id                                               name   host_id  \
# 0          2539                 Clean & quiet apt home by the park      2787
# 1          2595                              Skylit Midtown Castle      2845
# 2          3647                THE VILLAGE OF HARLEM....NEW YORK !      4632
# 3          3831                    Cozy Entire Floor of Brownstone      4869
# 4          5022   Entire Apt: Spacious Studio/Loft by central park      7192
# ...         ...                                                ...       ...
# 48890  36484665    Charming one bedroom - newly renovated rowhouse   8232441
# 48891  36485057      Affordable room in Bushwick/East Williamsburg   6570630
# 48892  36485431            Sunny Studio at Historical Neighborhood  23492952
# 48893  36485609               43rd St. Time Square-cozy single bed  30985759
# 48894  36487245  Trendy duplex in the very heart of Hell's Kitchen  68119814
#
# ...

# %% [markdown]
# ### Dataset Rows & Columns count

# %%
# Dataset Rows & Columns count

# computing number of rows
rows = len(df.axes[0])
 
# computing number of columns
cols = len(df.axes[1])

print(rows, cols)
# Out:
# 48895 16

# %% [markdown]
# ### Dataset Information

# %%
# Dataset Info
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 48895 entries, 0 to 48894
# Data columns (total 16 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   id                              48895 non-null  int64
#  1   name                            48879 non-null  object
#  2   host_id                         48895 non-null  int64
#  3   host_name                       48874 non-null  object
#  4   neighbourhood_group             48895 non-null  object
#  5   neighbourhood                   48895 non-null  object
#  6   latitude                        48895 non-null  float64
#  7   longitude                       48895 non-null  float64
#  8   room_type                       48895 non-null  object
#  9   price                           48895 non-null  int64
#  10  minimum_nights                  48895 non-null  int64
#  11  number_of_reviews               48895 non-null  int64
# ...

# %% [markdown]
# #### Duplicate Values

# %%
# Dataset Duplicate Value Count
dup = df.duplicated()
dup.value_counts()
# Out:
# False    48895
# dtype: int64

# %% [markdown]
# #### Missing Values/Null Values

# %%
# Missing Values/Null Values Count
null = df.isnull()
print(null)
null.value_counts()
# Out:
#           id   name  host_id  host_name  neighbourhood_group  neighbourhood  \
# 0      False  False    False      False                False          False
# 1      False  False    False      False                False          False
# 2      False  False    False      False                False          False
# 3      False  False    False      False                False          False
# 4      False  False    False      False                False          False
# ...      ...    ...      ...        ...                  ...            ...
# 48890  False  False    False      False                False          False
# 48891  False  False    False      False                False          False
# 48892  False  False    False      False                False          False
# 48893  False  False    False      False                False          False
# 48894  False  False    False      False                False          False
#
# ...

# %%
# Visualizing the missing values
msno.bar(df)

# %%
'''
Here, we see that in each column we need to have 48895 data,
but in columns name, host_name, last_review, review_per_month.
We have some missing values.
'''
# Out:
# '\nHere, we see that in each column we need to have 48895 data,\nbut in columns name, host_name, last_review, review_per_month.\nWe have some missing values.\n'

# %% [markdown]
# ### What did you know about your dataset?

# %% [markdown]
# What we undersatnd from data is that for the year 2019, airbnb data for new york has 48895 entries.
#
# Also due to some reasons there are missing values like Names and Host Names.
#
# We can also understand that guests/customers are not posting reviews as there are many missing values in review_per_month and last_review.

# %% [markdown]
# ## ***2. Understanding Your Variables***

# %%
# Dataset Columns
df.columns
# Out:
# Index(['id', 'name', 'host_id', 'host_name', 'neighbourhood_group',
#        'neighbourhood', 'latitude', 'longitude', 'room_type', 'price',
#        'minimum_nights', 'number_of_reviews', 'last_review',
#        'reviews_per_month', 'calculated_host_listings_count',
#        'availability_365'],
#       dtype='object')

# %%
# Dataset Describe
df.describe()
# Out:
#                  id       host_id      latitude     longitude         price  \
# count  4.889500e+04  4.889500e+04  48895.000000  48895.000000  48895.000000
# mean   1.901714e+07  6.762001e+07     40.728949    -73.952170    152.720687
# std    1.098311e+07  7.861097e+07      0.054530      0.046157    240.154170
# min    2.539000e+03  2.438000e+03     40.499790    -74.244420      0.000000
# 25%    9.471945e+06  7.822033e+06     40.690100    -73.983070     69.000000
# 50%    1.967728e+07  3.079382e+07     40.723070    -73.955680    106.000000
# 75%    2.915218e+07  1.074344e+08     40.763115    -73.936275    175.000000
# max    3.648724e+07  2.743213e+08     40.913060    -73.712990  10000.000000
#
#        minimum_nights  number_of_reviews  reviews_per_month  \
# count    48895.000000       48895.000000       38843.000000
# mean         7.029962          23.274466           1.373221
# std         20.510550          44.550582           1.680442
# ...

# %% [markdown]
# ### Variables Description

# %% [markdown]
# **Lets now understand about every column in the dataframe.**
#
# **'id'** => Unique ID assigned to the entry.
#
# **'name'** => This is a column containing the name provided by each host for customer reference.
#
# **'host_id' and 'host_name'** => Many hosts serve many objects. This "host_id" and "host_name" contains this records.
#
# **'neighbourhood' and 'neighbourhood_group'** => These columns contain information about the city and area of ​​properties offered by airbnb New York.
#
# **'Longitude' and 'Latitude'** => Contains the longitude and latitude of the property location.
#
# **'Room_type'** => Private room / entire home / shared room.
#
# **'price'** => An important column that contains price values ​​for all these properties.
#
# **'minimum_nights'** => This gives you information about the minimum number of nights a host offers for a particular accommodation.
#
# **'number_of_reviews' and 'reviews_month'** => It includes the number of reviews and ratings per month for these accommodations, as well as information about the host's hospitality.
#
# **'availabilty_365'** => Provides information about offer availability.Answer Here

# %% [markdown]
# ### Check Unique Values for each variable.

# %%
# Check Unique Values for each variable.
col_unique = df.columns.tolist()
for name in col_unique:
  print(df[name].unique())
# Out:
# [    2539     2595     3647 ... 36485431 36485609 36487245]
# ['Clean & quiet apt home by the park' 'Skylit Midtown Castle'
#  'THE VILLAGE OF HARLEM....NEW YORK !' ...
#  'Sunny Studio at Historical Neighborhood'
#  '43rd St. Time Square-cozy single bed'
#  "Trendy duplex in the very heart of Hell's Kitchen"]
# [     2787      2845      4632 ... 274321313  23492952  68119814]
# ['John' 'Jennifer' 'Elisabeth' ... 'Abayomi' 'Alberth' 'Ilgar & Aysel']
# ['Brooklyn' 'Manhattan' 'Queens' 'Staten Island' 'Bronx']
# ['Kensington' 'Midtown' 'Harlem' 'Clinton Hill' 'East Harlem'
#  'Murray Hill' 'Bedford-Stuyvesant' "Hell's Kitchen" 'Upper West Side'
#  'Chinatown' 'South Slope' 'West Village' 'Williamsburg' 'Fort Greene'
#  'Chelsea' 'Crown Heights' 'Park Slope' 'Windsor Terrace' 'Inwood'
#  'East Village' 'Greenpoint' 'Bushwick' 'Flatbush' 'Lower East Side'
#  'Prospect-Lefferts Gardens' 'Long Island City' 'Kips Bay' 'SoHo'
# ...

# %% [markdown]
# ## 3. ***Data Wrangling***

# %% [markdown]
# ### Data Wrangling Code

# %%
# Write your code to make your dataset analysis ready.
# First lets drop all the null values.
df.fillna(0, inplace=True) # This will replace all the null values to 0
df.head()
# Out:
#      id                                              name  host_id  \
# 0  2539                Clean & quiet apt home by the park     2787
# 1  2595                             Skylit Midtown Castle     2845
# 2  3647               THE VILLAGE OF HARLEM....NEW YORK !     4632
# 3  3831                   Cozy Entire Floor of Brownstone     4869
# 4  5022  Entire Apt: Spacious Studio/Loft by central park     7192
#
#      host_name neighbourhood_group neighbourhood  latitude  longitude  \
# 0         John            Brooklyn    Kensington  40.64749  -73.97237
# 1     Jennifer           Manhattan       Midtown  40.75362  -73.98377
# 2    Elisabeth           Manhattan        Harlem  40.80902  -73.94190
# 3  LisaRoxanne            Brooklyn  Clinton Hill  40.68514  -73.95976
# 4        Laura           Manhattan   East Harlem  40.79851  -73.94399
#
#          room_type  price  minimum_nights  number_of_reviews last_review  \
# ...

# %% [markdown]
# ### What all manipulations have you done and insights you found?

# %% [markdown]
# Since our dataset has everything needed for EDA we just have to replace the null values so that we can proceed further.

# %% [markdown]
# ## ***4. Data Vizualization, Storytelling & Experimenting with charts : Understand the relationships between variables***

# %% [markdown]
# #### Chart - 1 | Plot between neighbourhood_group and room_type (count)

# %%
# Chart - 1 visualization code
df.groupby(['neighbourhood_group'], dropna=True)['room_type'].value_counts()
plt.figure(figsize=(10,5))
sns.countplot(x='neighbourhood_group', hue='room_type', data=df)

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Because the count plot automatically count the number of values in each column here we only took the column 'neighbourhood_group'.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# From graph:-
#
# we can understand that the stay of customers are distributed amoung 5 Neighbourhood groups namely *Brooklyn, Manhattan, Queens, Staten Island, Bronx.*
#
# we can also understand that *Brooklyn* and *Manhattan* provides heighest number of Room type for their customers.
#
# room_type has three categories. We can also observe the number of accommodations of each room type in these five cities. In conclusion:-
#
# 1 - If we take the ratio of all room types we can clearly notice that only few people opt for shared room type.
#
# 2 - Most crowded places are Manhattan, brooklyn, Queens in the same order.
#
# 3 - The number of Privateroom and entire home is almost equal in every nrighbourhood group except Manhattan.
#
# 4 - In Manhattan most of the people went for entire home for their stay.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# **YES**, Gained insights will help creating positive business impact because now we know the preference for our customers where are they staying the most.
#
# As of now we can't really say about the negative growth maybe later we may witness some.

# %% [markdown]
# #### Chart - 2 | Plot between neighbourhood group and mean price

# %%
# Chart - 2 visualization code
plt.figure(figsize= (10,8))
mean_price_df = df.groupby(['neighbourhood_group', 'room_type'], as_index=False)[['price']].mean()
sns.barplot(data=mean_price_df, x='neighbourhood_group', y ='price', hue='room_type')

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# We choose barplot because it is the best and easy to understand the visualized data.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# we can conclude that:-
#
# 1- The entire home are really expensive.
#
# 2- The prices of private room and shared room which are somewhat comparable.
#
# 2- Amoung all the neighbourhood the most expensive one is Manhattan.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# **YES**, because now we know the price trend with neighbourhood_group and from chart-1 we know the preference of the guests.
#
# So, now we can update our prices in order to **maximize** our **Profit**.
#
# We can also say that there are some insight that leads to negative growth.
#
# That is, the **average price for Staten island is high as compared to Bronx and Queens** but from chart-1 we saw that **Staten Island has the least preference for our guests** that may cause **negative growth for our business**.

# %% [markdown]
# #### Chart - 3 | Relation between price and number_of_reviews

# %%
# Chart - 3 visualization code
sns.scatterplot(y=df['price'],x=df['number_of_reviews'],color='red')
plt.title('GRAPH 1')
# Out:
# Text(0.5, 1.0, 'GRAPH 1')

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Because Scatterplot is a classic way to visualize the distribution of one or more variables by counting the number of observations.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Here we found that maximum number of reviews are for low prices.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# **YES**, since feedback are the most valuable source of information for a business we can really use this information.
#
# **A big YES**. since there we a lot of null values in review column we may find it hard to know the customers and their needs. Plus there were rarely a review for higher prices we may not be able to provide the best service.

# %% [markdown]
# #### Chart - 4 | Relation between Number of reviews and Rewiews per month.

# %%
# Chart - 4 visualization code
sns.scatterplot(y=df['reviews_per_month'],x=df['number_of_reviews'],color='red')
plt.title('GRAPH 2')
# Out:
# Text(0.5, 1.0, 'GRAPH 2')

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Because Scatterplot is a classic way to visualize the distribution of one or more variables by counting the number of observations.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Since these two variables are highly correlated we can see the dese region in above chart.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# **YES**, since feedback are the most valuable source of information for a business we can really use this information.
#
# Reviews help our business to grow but if our clients are not posting any reviews
# it will be really hard for us to provide better service.

# %% [markdown]
# #### Chart - 5 | Plot between price and its frequency

# %%
# Chart - 5 visualization code
plt.figure(figsize = (10,7))
sns.histplot(data=df[df['price'] < 600], x="price", hue="neighbourhood_group", stat='frequency', element='poly')

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Histogram are the most recommended to study data collectively.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Here we can see that low prices are frequent the most and as we go to the higher onces we can see that frequency almost getting minimum values.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# **YES**, from above chart we can see the distribution of price. Also, looking at the data from chart 1 and 2, we can conclude that **Manhattan** is the most **expensive neighbourhood group** and the **price distriution of Manhattan from 0 to 100 is the most.**

# %% [markdown]
# #### Chart - 6 | Plot to show thee count of each neighbour hoood group.

# %%
# Chart - 6 visualization code
sns.countplot(data = df, x = 'neighbourhood_group')

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Because i wanted to show the total number of values of a univariate column called neighhbourhood_group.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# From above chart we can conclude that **Brooklyn** and **Manhattan** are the most **crowded place** in NewYork and most of the guests wants to visit these two as compared to other neighbourhood.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# **YES**, it will help us creating a positive business impact as we learned that most people prefer Brooklyn and Manhattan. we can customize our service based on this very Graph.
#
# Plus we can also learn the difference in service that are being provided be the most crowded neighbourhood_group in order to implement it to the least crowded neighbourhood_group.

# %% [markdown]
# #### Chart - 7 | Let's see the availability of different room types of each neighbourhood group

# %%
# Chart - 7 visualization code
plt.figure(figsize = (10,7))
sns.lineplot(data=df, x = 'neighbourhood_group', y = 'availability_365', hue = 'room_type')
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# I used line plot as it shows frequecy of data with a line.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# From above graph we can say that, Private room and Entire home is available at most in *STATEN ISLAND* but the availability of Shared rooms is lowest as compared to other neighbourhood groups.
# Also, The availability of Private rooms and Entire home is almost similar in *Brooklyn* and *Manhattan*.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# **YES**, with this chart we can clearly see that availability of Entire home/ private appartment is very low on the most preferrable neighbourborhood_group like *Manhattan* and *Brooklyn*. So, we need to manage the addition of as many listings as possible because of the popularity.
#
#
# we can also get negative growth as in Staten Islands the availability of Entrire home and Private room is the most. but the popularity is very low. So, what we can do is we can here make less available listings here and use that money on popular places.

# %% [markdown]
# #### Chart - 8 | Now we will analyze the data with the help of reviews we have recieved

# %%
# Chart - 8 visualization code
df['last_review'] = pd.to_datetime(df['last_review'], errors='coerce')
df['Days'], df['Month'], df['Years'] = (df['last_review'].dt.day, df['last_review'].dt.month, df['last_review'].dt.year)
df['last_review'] = pd.to_datetime(df['last_review']).dt.date


fig, axes = plt.subplots(nrows=1, ncols=2, figsize=(22, 6))
ax = axes.flatten()

sns.histplot(data=df, x='Days', hue='room_type', multiple="stack", ax=ax[0])
ax[0].set_title('No of Guest in days of the months')
sns.histplot(data=df, x='Month', hue='room_type', multiple="stack", ax=ax[1])
ax[1].set_title('No of Guest in months of the years')
sns.despine(fig, left=True)

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Histogram are the most recommended to study data collectively.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Before making conclusions we must keep in mind that these two predictions are based on the data user have provided but many users did not provide the reviews so we are restricted to those who did.
#
# From above two graphs we can say,
#
# 1- From left graph we observe that maximum number of guest is at the begining and the end of the months
#
# 2- From left graph also, in the middle of the months the number of guests is similar on average.
#
# 3- From right graph we observe that at the month of January and June there is this trend where the guests are maximum.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# There are insights for negative growth as so many people did not submit or post their feedbacks and reviews. Spo, it is hard for us to improve our business model. Moreover, if we did something wrong at providing service we may take a big loss for our business.

# %% [markdown]
# #### Chart - 9 | Count plot of Neighbourhood

# %%
# Chart - 9 visualization code
plt.figure(figsize = (16,7))
sns.countplot(data = df, x = 'neighbourhood', order = df.neighbourhood.value_counts().iloc[:10].index, hue = 'neighbourhood_group')

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Count plot is the best method to count the values of any variable. also it is the best to visualize univariate variable.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# From above graph we can say that **Williamsburg** and **Bedford-stuyvesant** are most listed neighbourhood.
#
# Also, we can see that these top ten neighbourhood are from **Manhattan** and **Brooklyn** neghbourhood_group.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# The gained insights are We must focus on **Manhattan** and **Brooklyn** neighbourhood_group and groom our services for the best. As, these two groups have set the bar of our services so, we must apply the same services on other neighbourhood_groups.

# %% [markdown]
# #### Chart - 10 | Let's find out which neighbourhood_group is expensive for Customers

# %%
# Chart - 10 visualization code
max_price_df = df.groupby('neighbourhood_group',as_index=False)['price'].max().sort_values(['price'],ascending = False).rename(columns = {'price':'Maximum price','neighbourhood_group':'Location'})
max_price_df
#max_price_df.plot(x='Location', y='Maximum price', style='o')
plt.figure(figsize = (10,7))
sns.barplot(data = max_price_df, x = 'Location', y = 'Maximum price' )

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Since we just need to see the frequency of our data we used this particular plot

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Clearly Manhattan, Brooklyn and Queens have the maximum rent price.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# **YES**, since we already know about the popularity and from above, the price. We can use these to create a positive impact. Because the first a client would ask that 'is this particular listing worth my money?' so its our job to maake them believe it is worth it, along with the goods we provide.

# %% [markdown]
# #### Chart - 11 | Let's check which host is highly suited for customers based on number_of_review

# %%
# Chart - 11 visualization code
host_df = df.groupby(['host_id','host_name'],as_index=False)['number_of_reviews'].sum().sort_values(['number_of_reviews'],ascending = False)
host_df1 = host_df.head(20)
host_df1
plt.figure(figsize = (10,7))
sns.lineplot(data = host_df1, y = 'host_name', x = 'number_of_reviews')

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Since i only needed to see the reviews of top 20 hosts i used line plot.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# We found that **Maya, Brooklyn & Breakfast-len-, Danielle, Yasu & Akiko and Brady** are the **most reviewed host_name** respectively.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# **YES**, now we know ur top 20 hosts who are reviewed by our clients. We can track their performance and see how they handle our clients, we can train other hosts in order to maximize our profit.

# %% [markdown]
# #### Chart - 12 | Tracking room_types based on Longitude and Latitude

# %%
# Chart - 12 visualization code
plt.figure(figsize=(10,6))
sns.scatterplot(df.longitude,df.latitude,hue=df.room_type)
# Out:
# /usr/local/lib/python3.8/dist-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# We used scatter plot specifically for the plot betwee n longitude and latitude because we would get whole New York covered. we can use our dataset(df) to compare it to New York map to get insights about the surroundings.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# We found that our dataset(df) almost trace New York. By knowing latitude and longitude we can add surroundings as services and we can get clear insights about the amneties we can add.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# **Yes**, as knowing the geography of our listings can really help providing the best for our clients.
# as the small business or amneties are keep increasing day by day we can really use them as a feature to show to our clients.

# %% [markdown]
# #### Chart - 13 | Chart - 6 but in **Pie-chart** type

# %%
# Chart - 13 visualization code
plt.figure(figsize=(5,5), dpi=100)
df['neighbourhood_group'].value_counts().plot(kind='pie',  autopct='%1.0f%%', startangle=360, fontsize=10)

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Pie charts are really interesting and clear to understand. it makes our analysis more professional.
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Manhattan is the city where most popular location with 44% of entire dataset. The least happend in Staten Island only 1%. Brooklyn consisted on 41% of transactions with 12% Queens and 2 % in Bronx.
#
#
# we can conclude that **Brooklyn** and **Manhattan** are the most **crowded place** in NewYork and most of the guests wants to visit these two as compared to other neighbourhood.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# **YES**, it will help us creating a positive business impact as we learned that most people prefer Brooklyn and Manhattan. we can customize our service based on this very Graph.
#
# Plus we can also learn the difference in service that are being provided be the most crowded neighbourhood_group in order to implement it to the least crowded neighbourhood_group.

# %% [markdown]
# #### Chart - 14 - Correlation Heatmap

# %%
# Correlation Heatmap visualization code
#since we donot need latitude, longitude, id, host_id, host_name ... here i am dropping these columns
newdf = set(df.columns) - {'latitude', 'longitude', 'id', 'host_id', 'host_name'} 
plt.figure(figsize=(10, 6))
heatmap = sns.heatmap(df[newdf].corr(), linewidths=0, vmin=-1, annot=True)
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Heatmap is a graphical representation of data. It shows the correlation between all the attributes with the attributes itself (so the correlation between same variable is 1).

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# We found the more general representation of numeric data of our attributes.
#
# we can comclude that:-
#
# 1- Number of reviews is highly correlated with reviews per month.
#
# 2-  Price is negatively correlated with reviews but correlated with availability_365, minimum_nights, calculated_host_listing_count.

# %% [markdown]
# #### Chart - 15 - Pair Plot

# %%
# Pair Plot visualization code
sns.pairplot(data=df)

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# In above graphs I am experimenting how much variable we have and their relationship with other variables pretty much like correlation matrix but in well visualized way.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Here we can conclude the same insights as the heatmap.

# %% [markdown]
# ## **5. Solution to Business Objective**

# %% [markdown]
# #### What do you suggest the client to achieve Business Objective ?
# Explain Briefly.

# %% [markdown]
# After analyzing the dataset, what i can really suggest to learn from the popular places and see the differnce between most and least preferable place and make least popular place more like popular place.
#
# Also, focus on the feedbacks and reviews. Make it interesting for our guests to leave a review each time they visit so that oiur business model can work really well and most importantly know our guests very well.

# %% [markdown]
# # **Conclusion**

# %% [markdown]
# The stay of customers are distributed amoung 5 neighbourhood_groups namely Brooklyn, Manhattan, Queens, Staten Island, Bronx. Most crowded places are Manhattan, brooklyn, Queens in the same order. Number of Private_room and entire home is almost equal in every nrighbourhood group in Manhattan.
#
# The price of an entire home/apt are very very high as compared to the prices of private room and shared room which are somewhat comparable. Amoung all the neighbourhood the most expensive one is Manhattan and it is located in the East Village area of New York City.
#
# Brooklyn and Manhattan are most expensive Neighbourhood groups.
#
# Brooklyn and Manhattan are the two most popular places to visit in New York City. Most of the guests wants to visit these two as compared to other neighbourhood. The availability of Private rooms and
#
# Entire home is almost similar in Brooklyn and Manhattan. However, the availability of Shared rooms is lowest as compared to other neighbourhood groups.
#
# Throughout the year maximum number of guests/customer visit neighbourhoods on January and June.
#
# we also plot Pairplot to see the relation between variable amoung different variables.
#
# Manhattan, Brooklyn and Queens have the most reviewed host_name. Maya, Brooklyn & Breakfast-len-, Danielle, Yasu & Akiko and Brady are the most popular hosts.

# %% [markdown]
# ### ***Hurrah! You have successfully completed your EDA Capstone Project !!!***
